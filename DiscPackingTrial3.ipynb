# %%
import numpy as np
import matplotlib.pyplot as plt

# radius of the circle
r = 0.1

# theta goes from 0 to 2pi for a 360 values
theta = np.linspace(0, 2*np.pi, 360)

# make x and y
x = r*np.cos(theta)
y = r*np.sin(theta)

#plot x and y
plt.plot(x,y)

#concatenate the two arrays into a single matrix of [x',y']
Cords=np.stack((x,y),axis=1)

# Randomly create an integer between 0 and 100.
Rand = (np.random.randint(360))

# Randommly select a cordinate from the circle
Chosen = Cords[Rand]


# plot the randomly selected cordinate
plt.scatter(Chosen[0],Chosen[1])

#Second Circle, orange
xNew= x + 2*(Chosen[0])
yNew= y + 2*(Chosen[1])
plt.plot(xNew,yNew) 


#third circle
# concatenate cords with cords so that I can add 60 degrees to the previously randomly selected cord even if it is already at 360
Cords= np.concatenate((Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords, Cords))
RandShift=Rand+60

#Choose a new random value shifted 60 degrees to the previous one.
Chosen = Cords[RandShift]

# plot the randomly selected cordinate
plt.scatter(Chosen[0],Chosen[1])

#Third Circle, green
xNew= x + 2*(Chosen[0])
yNew= y + 2*(Chosen[1])

plt.plot(xNew,yNew) 

#Fourth Circle, red
RandShift=RandShift+60
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 2*(Chosen[0])
yNew= y + 2*(Chosen[1])
plt.plot(xNew,yNew) 

#5 Circle, purple
RandShift=RandShift+60
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 2*(Chosen[0])
yNew= y + 2*(Chosen[1])
plt.plot(xNew,yNew) 

#6 Circle, brown
RandShift=RandShift+60
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 2*(Chosen[0])
yNew= y + 2*(Chosen[1])
plt.plot(xNew,yNew) 

#7 Circle, pink
RandShift=RandShift+60
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 2*(Chosen[0])
yNew= y + 2*(Chosen[1])
plt.plot(xNew,yNew) 

#8 Grey Circle, at this point I am moving onto layer 2, b.c. the 1 inner circle and 6 outer circles fill all the space now.
# I dont need to shift cords.. 
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#9 Circle, Need to shift at different angles now.. Yellow Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#10 Circle,Turquoise
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#11 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#12 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#13 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#14 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#15 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#16 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#17 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#18 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#19 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#20 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#21 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew) 

#22 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 4*(Chosen[0])
yNew= y + 4*(Chosen[1])
plt.plot(xNew,yNew) 

#23 Circle
RandShift=RandShift+30
Chosen = Cords[RandShift]
plt.scatter(Chosen[0],Chosen[1])
xNew= x + 3.5*(Chosen[0])
yNew= y + 3.5*(Chosen[1])
plt.plot(xNew,yNew)
